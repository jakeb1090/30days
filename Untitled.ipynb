# %%
import requests
from requests_html import HTML
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import pandas as pd
import time
from requests_html import HTMLSession

# %%
url = 'https://www.billboard.com/charts/rock-songs'

# %%
options = Options()
options.add_argument("--headless")
driver = webdriver.Chrome('c:/chromedriver/chromedriver.exe', options=options)
driver.get(url)

# %%
body_el = driver.find_element_by_css_selector('body')
html_str = body_el.get_attribute('innerHTML')
requests_obj = HTML(html=html_str)

# %%
rank_el = requests_obj.find('.chart-list-item__rank')
ranks = [x.text for x in rank_el]

title_el = requests_obj.find('.item-details__title')
titles = [x.text for x in title_el]

artist_el = requests_obj.find('.item-details__artist')
artists = [x.text for x in artist_el]

# %%
_dict = {
    'rank': ranks,
    'title': titles,
    'artist': artists,
    'genre': requests_obj.find('.print-chart__title')[0].text,
    'date': requests_obj.find('.print-chart__week')[0].text
    }

df = pd.DataFrame(data=_dict)
df
# Out:
#    rank                        title  \
# 0     1                         Mood
# 1     2                    Come & Go
# 2     3                    Death Bed
# 3     4                     Cardigan
# 4     5                    My Future
# 5     6                        Bang!
# 6     7          My Ex's Best Friend
# 7     8                        Exile
# 8     9           Moral Of The Story
# 9    10           Are You Bored Yet?
# 10   11             Bloody Valentine
# 11   12            My Tears Ricochet
# 12   13                       August
# 13   14              Man Of The Year
# 14   15             Level Of Concern
# 15   16                   Mirrorball
# 16   17              Hallucinogenics
# 17   18                        Seven
# 18   19        My Own Soul's Warning
# 19   20            This Is Me Trying
# 20   21  Eyes Blue Like The Atlantic
# 21   22      Can I Call You Tonight?
# 22   23               City Of Angels
# 23   24                    Mad Woman
# 24   25                     Mariposa
# 25   26                     Monsters
# 26   27               Someone To You
# 27   28                   Heat Waves
# 28   29                     Epiphany
# 29   30                        Peace
# 30   31                         Ohms
# 31   32                     Who Am I
# 32   33                         Hoax
# 33   34                     Daylight
# 34   35                   Wolf Totem
# 35   36                   Gimme Love
# 36   37                         Hero
# 37   38                  Overwhelmed
# 38   39                     Patience
# 39   40               Sick And Tired
# 40   41                     Blowback
# 41   42                        Freak
# 42   43              Angels & Demons
# 43   44                   Is It True
# 44   45                         Pray
# 45   46           Concert For Aliens
# 46   47                    Tangerine
# 47   48                Bad Decisions
# 48   49                        Ashes
# 49   50                  Hell N Back
#
#                                                artist  \
# 0                        24kGoldn Featuring iann dior
# 1                             Juice WRLD x Marshmello
# 2                         Powfu Featuring beabadoobee
# 3                                        Taylor Swift
# 4                                       Billie Eilish
# 5                                                 AJR
# 6                       Machine Gun Kelly X blackbear
# 7                     Taylor Swift Featuring Bon Iver
# 8                                                Ashe
# 9                            Wallows Featuring Clairo
# 10                                  Machine Gun Kelly
# 11                                       Taylor Swift
# 12                                       Taylor Swift
# 13                                         Juice WRLD
# 14                                  twenty one pilots
# 15                                       Taylor Swift
# 16                                        Matt Maeson
# 17                                       Taylor Swift
# 18                                        The Killers
# 19                                       Taylor Swift
# 20                       Sista_Prod Featuring Subvrbs
# 21                                            Dayglow
# 22                                           24kGoldn
# 23                                       Taylor Swift
# 24                                 Peach Tree Rascals
# 25                   All Time Low Featuring blackbear
# 26                                            BANNERS
# 27                                      Glass Animals
# 28                                       Taylor Swift
# 29                                       Taylor Swift
# 30                                           Deftones
# 31                                      NEEDTOBREATHE
# 32                                       Taylor Swift
# 33                                       Joji x Diplo
# 34                    The Hu Featuring Jacoby Shaddix
# 35                                               Joji
# 36                                             Weezer
# 37                                Royal & The Serpent
# 38                                      Chris Cornell
# 39  iann dior Featuring Machine Gun Kelly & Travis...
# 40                                        The Killers
# 41                        Sub Urban Featuring REI AMI
# 42                                               jxdn
# 43                                        Tame Impala
# 44                                               jxdn
# 45                                  Machine Gun Kelly
# 46                                      Glass Animals
# 47                                        The Strokes
# 48                                            Stellar
# 49                                              Bakar
#
#                            genre                           date
# 0   HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 1   HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 2   HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 3   HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 4   HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 5   HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 6   HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 7   HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 8   HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 9   HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 10  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 11  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 12  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 13  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 14  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 15  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 16  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 17  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 18  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 19  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 20  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 21  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 22  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 23  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 24  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 25  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 26  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 27  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 28  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 29  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 30  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 31  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 32  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 33  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 34  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 35  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 36  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 37  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 38  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 39  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 40  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 41  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 42  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 43  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 44  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 45  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 46  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 47  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 48  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020
# 49  HOT ROCK & ALTERNATIVE SONGS  The week of September 5, 2020

# %%
url = 'https://www.billboard.com/charts/e-songs'

def start_driver(url):
    options = Options()
    options.add_argument("--headless")
    driver = webdriver.Chrome('c:/chromedriver/chromedriver.exe', options=options)
    driver.get(url)
    return driver
    
def create_req_obj():
    body_el = driver.find_element_by_css_selector('body')
    html_str = body_el.get_attribute('innerHTML')
    requests_obj = HTML(html=html_str)
    return requests_obj
    
def get_data():
    rank_el = requests_obj.find('.chart-list-item__rank')
    ranks = [x.text for x in rank_el]

    title_el = requests_obj.find('.item-details__title')
    titles = [x.text for x in title_el]

    artist_el = requests_obj.find('.item-details__artist')
    artists = [x.text for x in artist_el]
    
    r_dict = {
    'rank': ranks,
    'title': titles,
    'artist': artists,
    'genre': requests_obj.find('.print-chart__title')[0].text,
    'date': requests_obj.find('.print-chart__week')[0].text
    }
    return r_dict

    
def to_output():
    df = pd.DataFrame(data=_dict)
    output_dict = df.T.to_dict()
    return output_dict

# %%
def process_page(url):
    driver = start_driver(url)
    requests_obj = create_req_obj()
    r_dict = get_data()
    output_dict = to_output()
    return output_dict

# %%
process_page(url)
# Out:
# {0: {'rank': '1',
#   'title': 'Mood',
#   'artist': '24kGoldn Featuring iann dior',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  1: {'rank': '2',
#   'title': 'Come & Go',
#   'artist': 'Juice WRLD x Marshmello',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  2: {'rank': '3',
#   'title': 'Death Bed',
#   'artist': 'Powfu Featuring beabadoobee',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  3: {'rank': '4',
#   'title': 'Cardigan',
#   'artist': 'Taylor Swift',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  4: {'rank': '5',
#   'title': 'My Future',
#   'artist': 'Billie Eilish',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  5: {'rank': '6',
#   'title': 'Bang!',
#   'artist': 'AJR',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  6: {'rank': '7',
#   'title': "My Ex's Best Friend",
#   'artist': 'Machine Gun Kelly X blackbear',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  7: {'rank': '8',
#   'title': 'Exile',
#   'artist': 'Taylor Swift Featuring Bon Iver',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  8: {'rank': '9',
#   'title': 'Moral Of The Story',
#   'artist': 'Ashe',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  9: {'rank': '10',
#   'title': 'Are You Bored Yet?',
#   'artist': 'Wallows Featuring Clairo',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  10: {'rank': '11',
#   'title': 'Bloody Valentine',
#   'artist': 'Machine Gun Kelly',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  11: {'rank': '12',
#   'title': 'My Tears Ricochet',
#   'artist': 'Taylor Swift',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  12: {'rank': '13',
#   'title': 'August',
#   'artist': 'Taylor Swift',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  13: {'rank': '14',
#   'title': 'Man Of The Year',
#   'artist': 'Juice WRLD',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  14: {'rank': '15',
#   'title': 'Level Of Concern',
#   'artist': 'twenty one pilots',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  15: {'rank': '16',
#   'title': 'Mirrorball',
#   'artist': 'Taylor Swift',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  16: {'rank': '17',
#   'title': 'Hallucinogenics',
#   'artist': 'Matt Maeson',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  17: {'rank': '18',
#   'title': 'Seven',
#   'artist': 'Taylor Swift',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  18: {'rank': '19',
#   'title': "My Own Soul's Warning",
#   'artist': 'The Killers',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  19: {'rank': '20',
#   'title': 'This Is Me Trying',
#   'artist': 'Taylor Swift',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  20: {'rank': '21',
#   'title': 'Eyes Blue Like The Atlantic',
#   'artist': 'Sista_Prod Featuring Subvrbs',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  21: {'rank': '22',
#   'title': 'Can I Call You Tonight?',
#   'artist': 'Dayglow',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  22: {'rank': '23',
#   'title': 'City Of Angels',
#   'artist': '24kGoldn',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  23: {'rank': '24',
#   'title': 'Mad Woman',
#   'artist': 'Taylor Swift',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  24: {'rank': '25',
#   'title': 'Mariposa',
#   'artist': 'Peach Tree Rascals',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  25: {'rank': '26',
#   'title': 'Monsters',
#   'artist': 'All Time Low Featuring blackbear',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  26: {'rank': '27',
#   'title': 'Someone To You',
#   'artist': 'BANNERS',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  27: {'rank': '28',
#   'title': 'Heat Waves',
#   'artist': 'Glass Animals',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  28: {'rank': '29',
#   'title': 'Epiphany',
#   'artist': 'Taylor Swift',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  29: {'rank': '30',
#   'title': 'Peace',
#   'artist': 'Taylor Swift',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  30: {'rank': '31',
#   'title': 'Ohms',
#   'artist': 'Deftones',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  31: {'rank': '32',
#   'title': 'Who Am I',
#   'artist': 'NEEDTOBREATHE',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  32: {'rank': '33',
#   'title': 'Hoax',
#   'artist': 'Taylor Swift',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  33: {'rank': '34',
#   'title': 'Daylight',
#   'artist': 'Joji x Diplo',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  34: {'rank': '35',
#   'title': 'Wolf Totem',
#   'artist': 'The Hu Featuring Jacoby Shaddix',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  35: {'rank': '36',
#   'title': 'Gimme Love',
#   'artist': 'Joji',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  36: {'rank': '37',
#   'title': 'Hero',
#   'artist': 'Weezer',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  37: {'rank': '38',
#   'title': 'Overwhelmed',
#   'artist': 'Royal & The Serpent',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  38: {'rank': '39',
#   'title': 'Patience',
#   'artist': 'Chris Cornell',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  39: {'rank': '40',
#   'title': 'Sick And Tired',
#   'artist': 'iann dior Featuring Machine Gun Kelly & Travis Barker',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  40: {'rank': '41',
#   'title': 'Blowback',
#   'artist': 'The Killers',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  41: {'rank': '42',
#   'title': 'Freak',
#   'artist': 'Sub Urban Featuring REI AMI',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  42: {'rank': '43',
#   'title': 'Angels & Demons',
#   'artist': 'jxdn',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  43: {'rank': '44',
#   'title': 'Is It True',
#   'artist': 'Tame Impala',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  44: {'rank': '45',
#   'title': 'Pray',
#   'artist': 'jxdn',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  45: {'rank': '46',
#   'title': 'Concert For Aliens',
#   'artist': 'Machine Gun Kelly',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  46: {'rank': '47',
#   'title': 'Tangerine',
#   'artist': 'Glass Animals',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  47: {'rank': '48',
#   'title': 'Bad Decisions',
#   'artist': 'The Strokes',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  48: {'rank': '49',
#   'title': 'Ashes',
#   'artist': 'Stellar',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'},
#  49: {'rank': '50',
#   'title': 'Hell N Back',
#   'artist': 'Bakar',
#   'genre': 'HOT ROCK & ALTERNATIVE SONGS',
#   'date': 'The week of September 5, 2020'}}
