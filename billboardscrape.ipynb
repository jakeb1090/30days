# %%
import requests
from requests_html import HTML
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import pandas as pd
import time
from requests_html import HTMLSession
import os

# %%
url = 'https://www.billboard.com/charts/rock-songs'

# %%
options = Options()
options.add_argument("--headless")
driver = webdriver.Chrome('c:/chromedriver/chromedriver.exe', options=options)
driver.get(url)

# %%
body_el = driver.find_element_by_css_selector('body')
html_str = body_el.get_attribute('innerHTML')
requests_obj = HTML(html=html_str)

# %%
rank_el = requests_obj.find('.chart-list-item__rank')
ranks = [x.text for x in rank_el]

title_el = requests_obj.find('.item-details__title')
titles = [x.text for x in title_el]

artist_el = requests_obj.find('.item-details__artist')
artists = [x.text for x in artist_el]

# %%
cwd = os.getcwd()
filepath = os.path.dirname(cwd)
filename = os.path.join(f"{df.date[0]}.csv", filepath)

# %%
# Out:
# 'The week of September 12, 2020'

# %%
_dict = {
    'rank': ranks,
    'title': titles,
    'artist': artists,
    'genre': requests_obj.find('.print-chart__title')[0].text,
    'date': requests_obj.find('.print-chart__week')[0].text
    }

df = pd.DataFrame(data=_dict)
df
# Out:
#    rank                        title  \
# 0     1                         Mood
# 1     2                    Come & Go
# 2     3                    Death Bed
# 3     4                     Cardigan
# 4     5                        Bang!
# 5     6          My Ex's Best Friend
# 6     7                    My Future
# 7     8                        Exile
# 8     9             Bloody Valentine
# 9    10           Moral Of The Story
# 10   11           Are You Bored Yet?
# 11   12                       August
# 12   13            My Tears Ricochet
# 13   14             Level Of Concern
# 14   15              Man Of The Year
# 15   16                   Nightlight
# 16   17                     Who Am I
# 17   18              Hallucinogenics
# 18   19  Eyes Blue Like The Atlantic
# 19   20      Can I Call You Tonight?
# 20   21                   Mirrorball
# 21   22                        Seven
# 22   23               City Of Angels
# 23   24                     Monsters
# 24   25            This Is Me Trying
# 25   26               Someone To You
# 26   27                     Mariposa
# 27   28                   Heat Waves
# 28   29                    Mad Woman
# 29   30                  Overwhelmed
# 30   31                        Peace
# 31   32                   Wolf Totem
# 32   33                   Gimme Love
# 33   34               Sick And Tired
# 34   35                        Freak
# 35   36                     Epiphany
# 36   37                     Daylight
# 37   38                     Patience
# 38   39                         Hoax
# 39   40                         Hero
# 40   41        My Own Soul's Warning
# 41   42                    Dangerous
# 42   43          All Within My Hands
# 43   44               Tokyo Drifting
# 44   45           Concert For Aliens
# 45   46                  Cabin Fever
# 46   47              Angels & Demons
# 47   48                  Hell N Back
# 48   49                   Bummerland
# 49   50                        Ashes
#
#                                                artist  \
# 0                        24kGoldn Featuring iann dior
# 1                             Juice WRLD x Marshmello
# 2                         Powfu Featuring beabadoobee
# 3                                        Taylor Swift
# 4                                                 AJR
# 5                       Machine Gun Kelly X blackbear
# 6                                       Billie Eilish
# 7                     Taylor Swift Featuring Bon Iver
# 8                                   Machine Gun Kelly
# 9                                                Ashe
# 10                           Wallows Featuring Clairo
# 11                                       Taylor Swift
# 12                                       Taylor Swift
# 13                                  twenty one pilots
# 14                                         Juice WRLD
# 15                                           ILLENIUM
# 16                                      NEEDTOBREATHE
# 17                                        Matt Maeson
# 18                       Sista_Prod Featuring Subvrbs
# 19                                            Dayglow
# 20                                       Taylor Swift
# 21                                       Taylor Swift
# 22                                           24kGoldn
# 23                   All Time Low Featuring blackbear
# 24                                       Taylor Swift
# 25                                            BANNERS
# 26                                 Peach Tree Rascals
# 27                                      Glass Animals
# 28                                       Taylor Swift
# 29                                Royal & The Serpent
# 30                                       Taylor Swift
# 31                    The Hu Featuring Jacoby Shaddix
# 32                                               Joji
# 33  iann dior Featuring Machine Gun Kelly & Travis...
# 34                        Sub Urban Featuring REI AMI
# 35                                       Taylor Swift
# 36                                       Joji x Diplo
# 37                                      Chris Cornell
# 38                                       Taylor Swift
# 39                                             Weezer
# 40                                        The Killers
# 41                                            Seether
# 42               Metallica And San Francisco Symphony
# 43                       Glass Animals & Denzel Curry
# 44                                  Machine Gun Kelly
# 45                                              Jaden
# 46                                               jxdn
# 47                                              Bakar
# 48                                                AJR
# 49                                            Stellar
#
#                            genre                            date
# 0   HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 1   HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 2   HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 3   HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 4   HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 5   HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 6   HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 7   HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 8   HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 9   HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 10  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 11  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 12  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 13  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 14  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 15  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 16  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 17  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 18  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 19  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 20  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 21  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 22  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 23  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 24  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 25  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 26  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 27  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 28  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 29  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 30  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 31  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 32  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 33  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 34  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 35  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 36  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 37  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 38  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 39  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 40  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 41  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 42  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 43  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 44  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 45  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 46  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 47  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 48  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020
# 49  HOT ROCK & ALTERNATIVE SONGS  The week of September 12, 2020

# %%
url = 'https://www.billboard.com/charts/e-songs'

def start_driver(url):
    options = Options()
    options.add_argument("--headless")
    driver = webdriver.Chrome('c:/chromedriver/chromedriver.exe', options=options)
    driver.get(url)
    return driver
    
def create_req_obj():
    body_el = driver.find_element_by_css_selector('body')
    html_str = body_el.get_attribute('innerHTML')
    requests_obj = HTML(html=html_str)
    return requests_obj
    
def get_data():
    rank_el = requests_obj.find('.chart-list-item__rank')
    ranks = [x.text for x in rank_el]

    title_el = requests_obj.find('.item-details__title')
    titles = [x.text for x in title_el]

    artist_el = requests_obj.find('.item-details__artist')
    artists = [x.text for x in artist_el]
    
    r_dict = {
    'rank': ranks,
    'title': titles,
    'artist': artists,
    'genre': requests_obj.find('.print-chart__title')[0].text,
    'date': requests_obj.find('.print-chart__week')[0].text
    }
    return r_dict

    
def to_output():
    df = pd.DataFrame(data=_dict)
    output_dict = df.T.to_dict()
    return output_dict

# %%
# def process_page(url):
#     driver = start_driver(url)
#     requests_obj = create_req_obj()
#     r_dict = get_data()
#     output_dict = to_output()
#     return output_dict

def process_page(url):
    driver = start_driver(url)
    requests_obj = create_req_obj()
    r_dict = get_data()
    output_dict = to_output()
    df = pd.DataFrame(output_dict)
    df.to_csv('charts.csv')
